# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanusharer/DL-practise/blob/main/keras03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 CNN Hyperparameter Optimization with Keras Tuner
# ### Fashion MNIST Classification
#
# ---
#
# **Author:** Dhanush
# **Framework:** TensorFlow / Keras
# **Hardware:** Tesla T4 GPU (Google Colab)
# **Dataset:** Fashion MNIST (70,000 grayscale images, 10 classes)
#
# ---
#
# ## 📌 Objective
#
# Build a **Convolutional Neural Network (CNN)** for image classification on the Fashion MNIST dataset and use **Keras Tuner** to automatically find the optimal hyperparameters — eliminating guesswork and replacing it with systematic search.
#
# ## 🗂️ Notebook Structure
#
# | Step | Description |
# |------|-------------|
# | 1 | Environment Setup & GPU Verification |
# | 2 | Install Dependencies |
# | 3 | Import Libraries |
# | 4 | Load & Preprocess Data |
# | 5 | Define Tunable Model Architecture |
# | 6 | Run Hyperparameter Search |
# | 7 | Train Best Model & Evaluate |
# | 8 | Results & Conclusions |

# %% [markdown]
# ---
# ## Step 1 — Environment Setup & GPU Verification
#
# We verify that a **GPU is available** before training. Training CNNs on a GPU is significantly faster than CPU — typically **10–20x** speedup for this task.
#
# > ⚙️ In Colab: `Runtime → Change runtime type → GPU` to enable GPU acceleration.

# %%
import tensorflow as tf
from tensorflow.python.client import device_lib

# Check GPU availability
print(f"TensorFlow Version : {tf.__version__}")
print(f"GPU Available      : {tf.test.is_gpu_available()}")
print("\n--- Available Devices ---")
for device in device_lib.list_local_devices():
    print(f"  [{device.device_type}] {device.name}")
    if device.device_type == 'GPU':
        print(f"         Memory : {device.memory_limit / 1e9:.2f} GB")
        print(f"         Desc   : {device.physical_device_desc}")
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_10268/3870539318.py:6: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# TensorFlow Version : 2.19.0
# GPU Available      : True
#
# --- Available Devices ---
#   [CPU] /device:CPU:0
#   [GPU] /device:GPU:0
#          Memory : 14.43 GB
#          Desc   : device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5

# %% [markdown]
# ---
# ## Step 2 — Install Dependencies
#
# **Keras Tuner** is the hyperparameter optimization library we use. It supports multiple search strategies:
#
# | Strategy | Description |
# |----------|-------------|
# | `RandomSearch` | Randomly samples from the hyperparameter space |
# | `Hyperband` | Resource-efficient variant of random search |
# | `BayesianOptimization` | Uses past results to guide future search |
#
# We use **RandomSearch** here as a clear, explainable baseline.

# %%
# !pip install keras-tuner --quiet
print("✅ keras-tuner installed successfully")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 6.2 MB/s eta 0:00:00
# ✅ keras-tuner installed successfully

# %% [markdown]
# ---
# ## Step 3 — Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt
import numpy as np
import matplotlib.pyplot as plt

print(f"TensorFlow : {tf.__version__}")
print(f"Keras      : {keras.__version__}")
print(f"Keras Tuner: {kt.__version__}")
# Out:
# TensorFlow : 2.19.0
# Keras      : 3.13.2
# Keras Tuner: 1.4.8

# %% [markdown]
# ---
# ## Step 4 — Load & Preprocess Data
#
# ### About Fashion MNIST
# Fashion MNIST is a drop-in replacement for the classic MNIST digits dataset, containing **70,000 grayscale images** (28×28 pixels) across **10 clothing categories**:
#
# | Label | Class | Label | Class |
# |-------|-------|-------|-------|
# | 0 | T-shirt/top | 5 | Sandal |
# | 1 | Trouser | 6 | Shirt |
# | 2 | Pullover | 7 | Sneaker |
# | 3 | Dress | 8 | Bag |
# | 4 | Coat | 9 | Ankle boot |
#
# ### Preprocessing Steps
# 1. **Normalize** pixel values from `[0, 255]` → `[0.0, 1.0]` — helps gradient descent converge faster
# 2. **Reshape** from `(N, 28, 28)` → `(N, 28, 28, 1)` — CNNs expect a channel dimension

# %%
# Load dataset
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()

print("Raw shapes:")
print(f"  Train images : {train_images.shape}  | Labels: {train_labels.shape}")
print(f"  Test images  : {test_images.shape}   | Labels: {test_labels.shape}")

# Normalize pixel values to [0, 1]
train_images = train_images / 255.0
test_images  = test_images  / 255.0

# Add channel dimension for CNN input (height, width, channels)
train_images = train_images.reshape(-1, 28, 28, 1)
test_images  = test_images.reshape(-1, 28, 28, 1)

print("\nAfter preprocessing:")
print(f"  Train images : {train_images.shape}")
print(f"  Test images  : {test_images.shape}")
print(f"  Pixel range  : [{train_images.min():.1f}, {train_images.max():.1f}]")
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Raw shapes:
#   Train images : (60000, 28, 28)  | Labels: (60000,)
#   Test images  : (10000, 28, 28)   | Labels: (10000,)
#
# After preprocessing:
#   Train images : (60000, 28, 28, 1)
#   Test images  : (10000, 28, 28, 1)
#   Pixel range  : [0.0, 1.0]

# %%
# Visualize sample images from each class
CLASS_NAMES = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

fig, axes = plt.subplots(2, 5, figsize=(14, 6))
fig.suptitle('Fashion MNIST — One Sample per Class', fontsize=14, fontweight='bold')

for label, ax in enumerate(axes.flat):
    idx = np.where(train_labels == label)[0][0]
    ax.imshow(train_images[idx].squeeze(), cmap='gray')
    ax.set_title(f'{label}: {CLASS_NAMES[label]}', fontsize=9)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 5 — Define Tunable CNN Architecture
#
# Instead of fixing hyperparameters manually, we define a **model-building function** that accepts a `hp` (HyperParameters) object. Keras Tuner will call this function repeatedly with different values to find the best combination.
#
# ### Hyperparameters Being Tuned
#
# | Hyperparameter | Search Space | Description |
# |---|---|---|
# | `conv_1_filter` | 32 → 128 (step 16) | Number of conv filters in layer 1 |
# | `conv_1_kernel` | {3, 5} | Kernel size (3×3 or 5×5) |
# | `conv_2_filter` | 32 → 128 (step 16) | Number of conv filters in layer 2 |
# | `dense_1_units` | 32 → 256 (step 32) | Neurons in the fully-connected layer |
# | `dropout_rate` | 0.2 → 0.5 (step 0.1) | Dropout for regularization |
# | `learning_rate` | {1e-2, 1e-3} | Adam optimizer learning rate |
#
# ### Architecture
# ```
# Input (28×28×1)
#     → Conv2D (tunable filters, tunable kernel, ReLU)
#     → MaxPooling2D (2×2)
#     → Conv2D (tunable filters, 3×3, ReLU)
#     → MaxPooling2D (2×2)
#     → Flatten
#     → Dense (tunable units, ReLU)
#     → Dropout (tunable rate)
#     → Dense (10, Softmax)  ← Output
# ```

# %%
def build_model(hp):
    """
    Builds a CNN with tunable hyperparameters for Fashion MNIST classification.

    Args:
        hp: keras_tuner HyperParameters object

    Returns:
        Compiled Keras model
    """
    model = keras.Sequential([
        # Input layer
        keras.layers.Input(shape=(28, 28, 1)),

        # --- Convolutional Block 1 ---
        keras.layers.Conv2D(
            filters=hp.Int('conv_1_filter', min_value=32, max_value=128, step=16),
            kernel_size=hp.Choice('conv_1_kernel', values=[3, 5]),
            activation='relu',
            padding='same'
        ),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),

        # --- Convolutional Block 2 ---
        keras.layers.Conv2D(
            filters=hp.Int('conv_2_filter', min_value=32, max_value=128, step=16),
            kernel_size=3,
            activation='relu',
            padding='same'
        ),
        keras.layers.MaxPooling2D(pool_size=(2, 2)),

        # --- Classifier Head ---
        keras.layers.Flatten(),
        keras.layers.Dense(
            units=hp.Int('dense_1_units', min_value=32, max_value=256, step=32),
            activation='relu'
        ),
        keras.layers.Dropout(rate=hp.Float('dropout_rate', min_value=0.2, max_value=0.5, step=0.1)),
        keras.layers.Dense(10, activation='softmax')
    ])

    model.compile(
        optimizer=keras.optimizers.Adam(
            learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3])
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model


# Sanity check — build with default HP values
sample_hp = kt.HyperParameters()
sample_model = build_model(sample_hp)
sample_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1568)           │             0 │
# ...

# %% [markdown]
# ---
# ## Step 6 — Hyperparameter Search
#
# We configure **RandomSearch** with the following settings:
#
# | Setting | Value | Meaning |
# |---------|-------|--------|
# | `objective` | `val_accuracy` | Metric to maximize |
# | `max_trials` | `5` | Number of different HP combinations to try |
# | `executions_per_trial` | `1` | How many times each trial runs (increase for stability) |
#
# > 💡 **Tip:** Increase `max_trials` to `15–20` for more thorough exploration on a real project. Here we use 5 for speed.

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=1,
    directory='kt_output',
    project_name='fashion_mnist_cnn',
    overwrite=True
)

# Display the search space summary
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 6
# conv_1_filter (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# conv_1_kernel (Choice)
# {'default': 3, 'conditions': [], 'values': [3, 5], 'ordered': True}
# conv_2_filter (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 128, 'step': 16, 'sampling': 'linear'}
# dense_1_units (Int)
# {'default': None, 'conditions': [], 'min_value': 32, 'max_value': 256, 'step': 32, 'sampling': 'linear'}
# dropout_rate (Float)
# {'default': 0.2, 'conditions': [], 'min_value': 0.2, 'max_value': 0.5, 'step': 0.1, 'sampling': 'linear'}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001], 'ordered': True}

# %%
# Early stopping callback — stops if val_accuracy doesn't improve
stop_early = keras.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=3,
    restore_best_weights=True,
    verbose=1
)

print("🔍 Starting hyperparameter search...")
print("   This will try 5 different configurations.\n")

tuner.search(
    train_images,
    train_labels,
    epochs=10,
    validation_split=0.1,
    callbacks=[stop_early],
    verbose=1
)

print("\n✅ Hyperparameter search complete!")
# Out:
# Trial 5 Complete [00h 01m 14s]
# val_accuracy: 0.8705000281333923
#
# Best val_accuracy So Far: 0.9254999756813049
# Total elapsed time: 00h 06m 10s
#
# ✅ Hyperparameter search complete!

# %% [markdown]
# ---
# ## Step 7 — Train the Best Model
#
# After the search, we:
# 1. Retrieve the **best hyperparameters** found
# 2. Build the final model with those parameters
# 3. Train it for more epochs on the **full training set** for maximum accuracy

# %%
# Retrieve best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

print("🏆 Best Hyperparameters Found:")
print(f"   Conv Layer 1 Filters : {best_hps.get('conv_1_filter')}")
print(f"   Conv Layer 1 Kernel  : {best_hps.get('conv_1_kernel')}x{best_hps.get('conv_1_kernel')}")
print(f"   Conv Layer 2 Filters : {best_hps.get('conv_2_filter')}")
print(f"   Dense Layer Units    : {best_hps.get('dense_1_units')}")
print(f"   Dropout Rate         : {best_hps.get('dropout_rate')}")
print(f"   Learning Rate        : {best_hps.get('learning_rate')}")
# Out:
# 🏆 Best Hyperparameters Found:
#    Conv Layer 1 Filters : 80
#    Conv Layer 1 Kernel  : 5x5
#    Conv Layer 2 Filters : 96
#    Dense Layer Units    : 192
#    Dropout Rate         : 0.4
#    Learning Rate        : 0.001

# %%
# Build final model with optimal hyperparameters
final_model = tuner.hypermodel.build(best_hps)

# Training callbacks
callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
]

print("🚀 Training the best model...\n")

history = final_model.fit(
    train_images,
    train_labels,
    epochs=20,
    validation_split=0.1,
    callbacks=callbacks,
    verbose=1
)
# Out:
# 🚀 Training the best model...
#
# Epoch 1/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 6ms/step - accuracy: 0.8382 - loss: 0.4515 - val_accuracy: 0.8907 - val_loss: 0.2992 - learning_rate: 0.0010
# Epoch 2/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8929 - loss: 0.2928 - val_accuracy: 0.9047 - val_loss: 0.2556 - learning_rate: 0.0010
# Epoch 3/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9083 - loss: 0.2488 - val_accuracy: 0.9088 - val_loss: 0.2399 - learning_rate: 0.0010
# Epoch 4/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9196 - loss: 0.2186 - val_accuracy: 0.9143 - val_loss: 0.2247 - learning_rate: 0.0010
# Epoch 5/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9284 - loss: 0.1950 - val_accuracy: 0.9160 - val_loss: 0.2279 - learning_rate: 0.0010
# Epoch 6/20
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9354 - loss: 0.1725 - val_accuracy: 0.9200 - val_loss: 0.2283 - learning_rate: 0.0010
# Epoch 7/20
# ...

# %% [markdown]
# ---
# ## Step 8 — Results & Evaluation
#
# We evaluate the final model on the **held-out test set** (data the model has never seen) and visualize training curves to check for overfitting.

# %%
# Evaluate on test set
test_loss, test_acc = final_model.evaluate(test_images, test_labels, verbose=0)

print("=" * 40)
print("  Final Test Results")
print("=" * 40)
print(f"  Test Accuracy : {test_acc:.4f} ({test_acc*100:.2f}%)")
print(f"  Test Loss     : {test_loss:.4f}")
print("=" * 40)
# Out:
# ...
#   Final Test Results
# ...
#   Test Accuracy : 0.9273 (92.73%)
#   Test Loss     : 0.3834
# ...

# %%
# Plot training history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))
fig.suptitle('Training History — Best Model', fontsize=14, fontweight='bold')

# Accuracy
ax1.plot(history.history['accuracy'],     label='Train Accuracy', linewidth=2)
ax1.plot(history.history['val_accuracy'], label='Val Accuracy',   linewidth=2, linestyle='--')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Loss
ax2.plot(history.history['loss'],     label='Train Loss', linewidth=2)
ax2.plot(history.history['val_loss'], label='Val Loss',   linewidth=2, linestyle='--')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Visualize predictions on test samples
CLASS_NAMES = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

predictions = final_model.predict(test_images[:25], verbose=0)
predicted_labels = np.argmax(predictions, axis=1)

fig, axes = plt.subplots(5, 5, figsize=(14, 14))
fig.suptitle('Predictions on Test Set (Green = Correct, Red = Wrong)', fontsize=13, fontweight='bold')

for i, ax in enumerate(axes.flat):
    ax.imshow(test_images[i].squeeze(), cmap='gray')
    is_correct = predicted_labels[i] == test_labels[i]
    color = 'green' if is_correct else 'red'
    ax.set_title(
        f"Pred: {CLASS_NAMES[predicted_labels[i]]}\nTrue: {CLASS_NAMES[test_labels[i]]}",
        color=color, fontsize=8
    )
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## 📊 Summary
#
# ### What We Did
#
# 1. **Built a CNN** tailored for image classification on 28×28 grayscale fashion images
# 2. **Used Keras Tuner** to search for the best hyperparameter combination across the defined search space
# 3. **Trained the optimal model** with early stopping and learning rate reduction
# 4. **Evaluated on held-out test data** and visualized predictions
#
# ### Key Takeaways
#
# | Concept | What Was Learned |
# |---------|------------------|
# | **Hyperparameter Tuning** | Removes trial-and-error; systematically finds better configs |
# | **RandomSearch** | Fast, effective baseline search strategy |
# | **Early Stopping** | Prevents overfitting by stopping at peak val accuracy |
# | **Data Normalization** | Critical for stable training — always scale to [0, 1] |
# | **Channel Dimension** | CNNs require shape `(H, W, C)` — reshape before passing |
#
# ### Next Steps to Explore
#
# - 🔁 Try `kt.Hyperband` or `kt.BayesianOptimization` for smarter search
# - 🧩 Add **Batch Normalization** layers between Conv blocks
# - 📈 Use **Data Augmentation** (`ImageDataGenerator`) to improve generalization
# - 💾 Save the final model: `final_model.save('fashion_cnn_best.keras')`
#
# ---
# *This notebook is part of a Deep Learning practice series. See more at [github.com/dhanusharer/DL-practise](https://github.com/dhanusharer/DL-practise)*
