# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanusharer/DL-practise/blob/main/keras03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 CNN Hyperparameter Optimization on Fashion MNIST using Keras Tuner

# %%
# !pip install keras-tuner
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 7.9 MB/s eta 0:00:00
# ...

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np

# %%
print(tf.__version__)
# Out:
# 2.19.0

# %%
fashion_mnist=keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels)=fashion_mnist.load_data()
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
train_images=train_images/255.0
test_images=test_images/255.0

# %%
train_images=train_images.reshape(len(train_images),28,28,1)
test_images=test_images.reshape(len(test_images),28,28,1)

# %% [markdown]
# ## Step 1: Define the hypermodel
#
# In this notebook we use **Keras Tuner** to try a few CNN configurations automatically.
#
# ### What juniors should notice
# - `build_model(hp)` receives a hyperparameter object named `hp`.
# - Every `hp.Int(...)` or `hp.Choice(...)` describes a search space.
# - The tuner will train several models and compare them using `val_accuracy`.
# - We still compile the model normally with loss and metrics.
#
# ### Search space used here
# - Number of filters in the convolution layer
# - Kernel size for the convolution layer
# - Number of units in the dense hidden layer
# - Learning rate for Adam optimizer

# %%
def build_model(hp):
  model=keras.Sequential([
  keras.layers.Conv2D(
      filters=hp.Int('conv_1_filter',min_value=32,max_value=128,step=16),
      kernel_size=hp.Choice('conv_1_kernel',values=[3,5]),
      activation='relu',
      input_shape=(28,28,1)
  ),
  keras.layers.Flatten(),
  keras.layers.Dense(
      units=hp.Int('dense_1_units',min_value=32,max_value=128,step=16),
      activation='relu'
  ),
  keras.layers.Dense(10,activation='softmax')
  ])
  model.compile(optimizer=keras.optimizers.Adam(hp.Choice('learning_rate',values=[1e-2,1e-3])),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])
  return model

# %%
try:
    import keras_tuner as kt
except ImportError:
    import kerastuner as kt

# RandomSearch will sample a few combinations from our search space.
tuner_search = kt.RandomSearch(
    hypermodel=build_model,
    objective='val_accuracy',
    max_trials=5,
    directory='output',
    project_name='mnist_fashion_tuning'
)

# A quick summary helps juniors see what is being tuned.
tuner_search.search_space_summary()

# %%
# Run the hyperparameter search.
tuner_search.search(train_images, train_labels, epochs=3, validation_split=0.1)

# Get the best hyperparameters discovered during the search.
best_hps = tuner_search.get_best_hyperparameters(num_trials=1)[0]

print('Best filter count:', best_hps.get('conv_1_filter'))
print('Best kernel size:', best_hps.get('conv_1_kernel'))
print('Best dense units:', best_hps.get('dense_1_units'))
print('Best learning rate:', best_hps.get('learning_rate'))

# %%
# Build the best model and train it once more.
best_model = tuner_search.hypermodel.build(best_hps)
history = best_model.fit(
    train_images,
    train_labels,
    epochs=5,
    validation_split=0.1
)

test_loss, test_accuracy = best_model.evaluate(test_images, test_labels, verbose=0)
print(f'Test loss: {test_loss:.4f}')
print(f'Test accuracy: {test_accuracy:.4f}')

# %% [markdown]
# # 🧠 CNN Hyperparameter Tuning using Keras Tuner
#
# This project demonstrates:
# - Building a CNN model using TensorFlow/Keras
# - Hyperparameter tuning using Keras Tuner
# - Training on Fashion MNIST dataset
#
# 🎯 Goal: Optimize model performance automatically

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# %% [markdown]
# ## ⚙️ Checking TensorFlow Version & GPU

# %%
print("TensorFlow Version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow Version: 2.19.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
## 📦 Install Keras Tuner

# %%
# !pip install -q keras-tuner
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 6.9 MB/s eta 0:00:00

# %% [markdown]
# ## 📊 Load and Explore Dataset (Fashion MNIST)

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

print("Train shape:", train_images.shape)
print("Test shape:", test_images.shape)
# Out:
# ...
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ...
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Train shape: (60000, 28, 28)
# Test shape: (10000, 28, 28)

# %% [markdown]
# ## 🧹 Data Preprocessing
# - Normalize pixel values
# - Reshape for CNN input

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

train_images = train_images.reshape(-1, 28, 28, 1)
test_images = test_images.reshape(-1, 28, 28, 1)

# %% [markdown]
# ## 🏗️ CNN Model with Hyperparameter Tuning

# %%
def build_model(hp):
    model = keras.Sequential()

    # Conv Layer
    model.add(layers.Conv2D(
        filters=hp.Int('filters', min_value=32, max_value=128, step=32),
        kernel_size=(3,3),
        activation='relu',
        input_shape=(28,28,1)
    ))

    model.add(layers.MaxPooling2D((2,2)))
    model.add(layers.Flatten())

    # Dense Layer
    model.add(layers.Dense(
        units=hp.Int('units', min_value=64, max_value=256, step=64),
        activation='relu'
    ))

    model.add(layers.Dense(10, activation='softmax'))

    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    return model

# %% [markdown]
# ## 🔍 Hyperparameter Search using RandomSearch

# %%
from keras_tuner import RandomSearch

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=3,
    directory='tuner_dir',
    project_name='fashion_mnist'
)

tuner.search(
    train_images,
    train_labels,
    epochs=3,
    validation_split=0.2
)

# Get best model
best_model = tuner.get_best_models(num_models=1)[0]

# Evaluate
test_loss, test_acc = best_model.evaluate(test_images, test_labels)
print("Test Accuracy:", test_acc)
# Out:
# Trial 3 Complete [00h 00m 23s]
# val_accuracy: 0.8882499933242798
#
# Best val_accuracy So Far: 0.906000018119812
# Total elapsed time: 00h 01m 20s
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_lib.py:802: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 14 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9042 - loss: 0.2755
# Test Accuracy: 0.9053999781608582

# %% [markdown]
# ## 📈 Training Performance Visualization
#
# This section shows how the model improves over epochs:
# - Accuracy trend
# - Loss reduction

# %%
import matplotlib.pyplot as plt

# Get the best hyperparameters from the tuner
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the best model
best_model = tuner.hypermodel.build(best_hps)

# Train the best model and store its training history
history = best_model.fit(
    train_images,
    train_labels,
    epochs=5,
    validation_split=0.2
)

# Extract metrics
history_dict = history.history

acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# Plot Accuracy
plt.figure()
plt.plot(epochs, acc, label='Training Accuracy')
plt.plot(epochs, val_acc, label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot Loss
plt.figure()
plt.plot(epochs, loss, label='Training Loss')
plt.plot(epochs, val_loss, label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8290 - loss: 0.4879 - val_accuracy: 0.8918 - val_loss: 0.2942
# Epoch 2/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9082 - loss: 0.2501 - val_accuracy: 0.9069 - val_loss: 0.2521
# Epoch 3/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.9277 - loss: 0.1944 - val_accuracy: 0.9086 - val_loss: 0.2621
# Epoch 4/5
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9407 - loss: 0.1531 - val_accuracy: 0.9162 - val_loss: 0.2515
# Epoch 5/5
# ...

# %% [markdown]
# ## 🔍 Confusion Matrix
#
# This helps visualize model performance across all classes.

# %%
class_names = [
    "T-shirt", "Trouser", "Pullover", "Dress",
    "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

plt.figure(figsize=(10,8))
sns.heatmap(cm, annot=True, fmt='d',
            xticklabels=class_names,
            yticklabels=class_names)

plt.title("Confusion Matrix (Fashion MNIST)")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ## 🔍 Confusion Matrix Analysis
#
# ### 📊 Key Observations:
# - Most predictions lie on the diagonal → model performs well overall
# - Strong performance in classes:
#   - Class 1, 5, 7, 8, 9 (high correct predictions)
#
# ### ⚠️ Misclassification Insights:
# - Class 6 is often confused with:
#   - Class 0 and 2
# - Class 4 shows confusion with:
#   - Class 2 and 3
#
# ### 💡 Interpretation:
# - Model struggles with visually similar categories
# - Indicates need for better feature extraction or deeper architecture

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels, y_pred_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87      1000
#            1       0.99      0.98      0.99      1000
#            2       0.82      0.90      0.86      1000
#            3       0.92      0.91      0.91      1000
#            4       0.83      0.87      0.85      1000
#            5       0.99      0.96      0.98      1000
#            6       0.81      0.69      0.75      1000
#            7       0.93      0.98      0.96      1000
#            8       0.97      0.98      0.98      1000
#            9       0.98      0.96      0.97      1000
#
#     accuracy                           0.91     10000
#    macro avg       0.91      0.91      0.91     10000
# weighted avg       0.91      0.91      0.91     10000

# %% [markdown]
# ## 🧪 Basic Model Tests

# %%
# Test 1: Check model prediction shape
assert y_pred.shape[0] == len(test_images)
print("✅ Prediction shape test passed")

# Test 2: Check accuracy threshold
_, acc = best_model.evaluate(test_images, test_labels)
assert acc > 0.7
print("✅ Accuracy test passed")

# Test 3: Check output classes
assert y_pred.shape[1] == 10
print("✅ Output class test passed")
# Out:
# ✅ Prediction shape test passed
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9090 - loss: 0.2693
# ✅ Accuracy test passed
# ✅ Output class test passed

# %%
# Test 1: Prediction shape
assert y_pred.shape == (len(test_images), 10)
print("✅ Prediction shape correct")

# Test 2: Accuracy threshold
_, acc = best_model.evaluate(test_images, test_labels)
assert acc > 0.80
print("✅ Model accuracy is good")

# Test 3: No NaN values
assert not np.isnan(y_pred).any()
print("✅ No NaN values in predictions")

# Test 4: Class coverage
unique_classes = np.unique(y_pred_classes)
assert len(unique_classes) == 10
print("✅ All classes predicted")
# Out:
# ✅ Prediction shape correct
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9090 - loss: 0.2693
# ✅ Model accuracy is good
# ✅ No NaN values in predictions
# ✅ All classes predicted

# %%
class_names = [
    "T-shirt", "Trouser", "Pullover", "Dress",
    "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"
]

# %% [markdown]
# ## 🧠 Project Summary
#
# ### 📌 What I Did:
# - Built CNN model using TensorFlow
# - Applied Hyperparameter Tuning (Keras Tuner)
# - Evaluated using:
#   - Accuracy & Loss Graphs
#   - Confusion Matrix
#   - Classification Report
#
# ### 📊 Results:
# - Achieved optimized accuracy using tuning
# - Improved generalization on validation data
#
# ### 🚀 Future Improvements:
# - Add Dropout layers
# - Try different optimizers
# - Use deeper CNN architectures
